# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 0
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 0:
# Image - Min Value: 2 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    #return (x - np.amin(x)) / np.amax(x)
    return x / np.amax(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    # Eg: Map 0 to [1.0, 0.0, 0.0 ...], 2 to [0.0, 0.0, 1.0 ...] etc...
    one_hot_labels = [(np.arange(num_labels) == i) for i in x]
    return np.asarray(one_hot_labels)

num_labels = 10

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    tensor_dim = list(image_shape)
    tensor_dim.insert(0, None)
    return tf.placeholder(tf.float32, shape=tensor_dim, name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernel size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernel size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    color_channels = int(x_tensor.shape[-1:][0]) # should be 5
    weights = tf.Variable(tf.truncated_normal(
    conv_ksize + (color_channels,) + (conv_num_outputs,)))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    # Apply Convolution
    conv_layer = tf.nn.conv2d(x_tensor, weights, strides=list((1,) + conv_strides + (1,)), padding='SAME')
    # Add bias
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    # Apply activation function
    conv_layer = tf.nn.relu(conv_layer)
    # Second layer # max pooling
    pool = tf.nn.max_pool(conv_layer, list((1,)+pool_ksize+(1,)), list((1,)+pool_strides+(1,)), padding='SAME')
    return pool 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    reshape = tf.reshape(x_tensor, [tf.shape(x_tensor)[0], shape[1] * shape[2] * shape[3]])
    return reshape


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weights_conn = tf.Variable(tf.truncated_normal([tf.to_int32(x_tensor.shape[1]), num_outputs], stddev=1.0))
    biases_conn = tf.Variable(tf.constant(1.0, shape=[num_outputs]))
    return tf.nn.relu(tf.nn.bias_add(tf.matmul(x_tensor, weights_conn), biases_conn))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weights_out = tf.Variable(tf.truncated_normal([tf.to_int32(x_tensor.shape[1]), num_outputs], stddev=1.0))
    biases_out = tf.Variable(tf.constant(1.0, shape=[num_outputs]))
    return tf.nn.bias_add(tf.matmul(x_tensor, weights_out), biases_out)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_num_outputs = 96
    conv_ksize = (3,3)
    conv_strides = (1,1)
    pool_ksize = (2,2)
    pool_strides = (2,2)
    conv1 = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    # 2nd conv layer
#    conv_num_outputs = 64
#    conv_ksize = (5,5)
#    conv_strides = (1,1)
#    pool_ksize = (3,3)
#    pool_strides = (2,2)
#    conv2 = conv2d_maxpool(conv1, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    hidden_layer = flatten(conv1)
#    hidden_layer = flatten(conv2)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    num_outputs = 512
    hidden_layer = fully_conn(hidden_layer, num_outputs)
    # dropout
    hidden_layer = tf.nn.dropout(hidden_layer, keep_prob)
    
    # 2nd fully conn layer
#    num_outputs = 192
#    hidden_layer = fully_conn(hidden_layer, num_outputs)
    # dropout
#    hidden_layer = tf.nn.dropout(hidden_layer, keep_prob)    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    num_classes = 10
    output_layer = output(hidden_layer, num_classes)
    
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = 100.0*tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})
    return


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    cost, acc = session.run([cost, accuracy], feed_dict={x: valid_features, y: valid_labels, keep_prob:1})
    print('batch loss at current step: {}'.format(cost))
    print('Accuracy: %.2f%%' % acc)
    return

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 128
keep_probability = 1.0

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  batch loss at current step: 849.5975952148438
# Accuracy: 23.24%
# Epoch  2, CIFAR-10 Batch 1:  batch loss at current step: 618.0825805664062
# Accuracy: 29.04%
# Epoch  3, CIFAR-10 Batch 1:  batch loss at current step: 526.6729736328125
# Accuracy: 31.28%
# Epoch  4, CIFAR-10 Batch 1:  batch loss at current step: 442.5849914550781
# Accuracy: 33.68%
# Epoch  5, CIFAR-10 Batch 1:  batch loss at current step: 399.468994140625
# Accuracy: 35.80%
# Epoch  6, CIFAR-10 Batch 1:  batch loss at current step: 379.7662353515625
# Accuracy: 37.50%
# Epoch  7, CIFAR-10 Batch 1:  batch loss at current step: 361.7748107910156
# Accuracy: 38.20%
# Epoch  8, CIFAR-10 Batch 1:  batch loss at current step: 365.7291259765625
# Accuracy: 39.86%
# Epoch  9, CIFAR-10 Batch 1:  batch loss at current step: 361.5066223144531
# Accuracy: 39.02%
# Epoch 10, CIFAR-10 Batch 1:  batch loss at current step: 322.8305358886719
# Accuracy: 40.10%
# Epoch 11, CIFAR-10 Batch 1:  batch loss at current step: 322.6903381347656
# Accuracy: 39.32%
# Epoch 12, CIFAR-10 Batch 1:  batch loss at current step: 387.1361083984375
# Accuracy: 38.68%
# Epoch 13, CIFAR-10 Batch 1:  batch loss at current step: 343.2657470703125
# Accuracy: 40.10%
# Epoch 14, CIFAR-10 Batch 1:  batch loss at current step: 308.6660461425781
# Accuracy: 42.86%
# Epoch 15, CIFAR-10 Batch 1:  batch loss at current step: 367.6022033691406
# Accuracy: 41.98%
# Epoch 16, CIFAR-10 Batch 1:  batch loss at current step: 317.3169860839844
# Accuracy: 43.48%
# Epoch 17, CIFAR-10 Batch 1:  batch loss at current step: 336.29412841796875
# Accuracy: 44.32%
# Epoch 18, CIFAR-10 Batch 1:  batch loss at current step: 337.3771057128906
# Accuracy: 42.86%
# Epoch 19, CIFAR-10 Batch 1:  batch loss at current step: 387.0384216308594
# Accuracy: 41.72%
# Epoch 20, CIFAR-10 Batch 1:  batch loss at current step: 340.8027648925781
# Accuracy: 42.68%
# Epoch 21, CIFAR-10 Batch 1:  batch loss at current step: 339.3319091796875
# Accuracy: 44.32%
# Epoch 22, CIFAR-10 Batch 1:  batch loss at current step: 349.94451904296875
# Accuracy: 43.34%
# Epoch 23, CIFAR-10 Batch 1:  batch loss at current step: 378.6456604003906
# Accuracy: 40.92%
# Epoch 24, CIFAR-10 Batch 1:  batch loss at current step: 359.0900573730469
# Accuracy: 43.04%
# Epoch 25, CIFAR-10 Batch 1:  batch loss at current step: 309.375
# Accuracy: 45.74%
# Epoch 26, CIFAR-10 Batch 1:  batch loss at current step: 330.65802001953125
# Accuracy: 44.28%
# Epoch 27, CIFAR-10 Batch 1:  batch loss at current step: 342.02606201171875
# Accuracy: 43.02%
# Epoch 28, CIFAR-10 Batch 1:  batch loss at current step: 318.8680114746094
# Accuracy: 45.48%
# Epoch 29, CIFAR-10 Batch 1:  batch loss at current step: 288.6268615722656
# Accuracy: 46.60%
# Epoch 30, CIFAR-10 Batch 1:  batch loss at current step: 292.4786071777344
# Accuracy: 46.34%
# Epoch 31, CIFAR-10 Batch 1:  batch loss at current step: 314.7904052734375
# Accuracy: 45.34%
# Epoch 32, CIFAR-10 Batch 1:  batch loss at current step: 288.7782287597656
# Accuracy: 46.10%
# Epoch 33, CIFAR-10 Batch 1:  batch loss at current step: 265.0810852050781
# Accuracy: 46.72%
# Epoch 34, CIFAR-10 Batch 1:  batch loss at current step: 272.16265869140625
# Accuracy: 46.12%
# Epoch 35, CIFAR-10 Batch 1:  batch loss at current step: 329.5469055175781
# Accuracy: 42.66%
# Epoch 36, CIFAR-10 Batch 1:  batch loss at current step: 328.72021484375
# Accuracy: 43.82%
# Epoch 37, CIFAR-10 Batch 1:  batch loss at current step: 337.71429443359375
# Accuracy: 43.68%
# Epoch 38, CIFAR-10 Batch 1:  batch loss at current step: 319.01239013671875
# Accuracy: 44.52%
# Epoch 39, CIFAR-10 Batch 1:  batch loss at current step: 281.9525146484375
# Accuracy: 46.06%
# Epoch 40, CIFAR-10 Batch 1:  batch loss at current step: 276.9307861328125
# Accuracy: 46.44%
# Epoch 41, CIFAR-10 Batch 1:  batch loss at current step: 305.9662780761719
# Accuracy: 44.50%
# Epoch 42, CIFAR-10 Batch 1:  batch loss at current step: 259.2361145019531
# Accuracy: 47.84%
# Epoch 43, CIFAR-10 Batch 1:  batch loss at current step: 269.904052734375
# Accuracy: 46.22%
# Epoch 44, CIFAR-10 Batch 1:  batch loss at current step: 268.4998474121094
# Accuracy: 46.32%
# Epoch 45, CIFAR-10 Batch 1:  batch loss at current step: 301.65643310546875
# Accuracy: 44.08%
# Epoch 46, CIFAR-10 Batch 1:  batch loss at current step: 281.11944580078125
# Accuracy: 46.36%
# Epoch 47, CIFAR-10 Batch 1:  batch loss at current step: 289.8147277832031
# Accuracy: 45.98%
# Epoch 48, CIFAR-10 Batch 1:  batch loss at current step: 281.13604736328125
# Accuracy: 46.36%
# Epoch 49, CIFAR-10 Batch 1:  batch loss at current step: 281.1595458984375
# Accuracy: 46.04%
# Epoch 50, CIFAR-10 Batch 1:  batch loss at current step: 281.8365478515625
# Accuracy: 45.96%
# Epoch 51, CIFAR-10 Batch 1:  batch loss at current step: 287.4020080566406
# Accuracy: 45.96%
# Epoch 52, CIFAR-10 Batch 1:  batch loss at current step: 258.07275390625
# Accuracy: 48.76%
# Epoch 53, CIFAR-10 Batch 1:  batch loss at current step: 236.7960968017578
# Accuracy: 49.88%
# Epoch 54, CIFAR-10 Batch 1:  batch loss at current step: 241.4998321533203
# Accuracy: 49.14%
# Epoch 55, CIFAR-10 Batch 1:  batch loss at current step: 236.28285217285156
# Accuracy: 49.10%
# Epoch 56, CIFAR-10 Batch 1:  batch loss at current step: 235.05908203125
# Accuracy: 49.36%
# Epoch 57, CIFAR-10 Batch 1:  batch loss at current step: 231.56085205078125
# Accuracy: 49.34%
# Epoch 58, CIFAR-10 Batch 1:  batch loss at current step: 233.48765563964844
# Accuracy: 49.36%
# Epoch 59, CIFAR-10 Batch 1:  batch loss at current step: 237.80831909179688
# Accuracy: 49.72%
# Epoch 60, CIFAR-10 Batch 1:  batch loss at current step: 232.82940673828125
# Accuracy: 49.86%
# Epoch 61, CIFAR-10 Batch 1:  batch loss at current step: 238.48841857910156
# Accuracy: 49.24%
# Epoch 62, CIFAR-10 Batch 1:  batch loss at current step: 235.7915802001953
# Accuracy: 49.32%
# Epoch 63, CIFAR-10 Batch 1:  batch loss at current step: 240.16310119628906
# Accuracy: 49.70%
# Epoch 64, CIFAR-10 Batch 1:  batch loss at current step: 233.6585235595703
# Accuracy: 50.02%
# Epoch 65, CIFAR-10 Batch 1:  batch loss at current step: 238.4176025390625
# Accuracy: 48.96%
# Epoch 66, CIFAR-10 Batch 1:  batch loss at current step: 250.12985229492188
# Accuracy: 49.26%
# Epoch 67, CIFAR-10 Batch 1:  batch loss at current step: 242.04104614257812
# Accuracy: 49.28%
# Epoch 68, CIFAR-10 Batch 1:  batch loss at current step: 244.4357452392578
# Accuracy: 48.28%
# Epoch 69, CIFAR-10 Batch 1:  batch loss at current step: 248.3931427001953
# Accuracy: 49.30%
# Epoch 70, CIFAR-10 Batch 1:  batch loss at current step: 239.49952697753906
# Accuracy: 49.78%
# Epoch 71, CIFAR-10 Batch 1:  batch loss at current step: 248.98162841796875
# Accuracy: 49.90%
# Epoch 72, CIFAR-10 Batch 1:  batch loss at current step: 240.9437713623047
# Accuracy: 49.74%
# Epoch 73, CIFAR-10 Batch 1:  batch loss at current step: 246.75259399414062
# Accuracy: 48.82%
# Epoch 74, CIFAR-10 Batch 1:  batch loss at current step: 248.9710235595703
# Accuracy: 49.16%
# Epoch 75, CIFAR-10 Batch 1:  batch loss at current step: 240.10354614257812
# Accuracy: 49.26%
# Epoch 76, CIFAR-10 Batch 1:  batch loss at current step: 248.29469299316406
# Accuracy: 49.50%
# Epoch 77, CIFAR-10 Batch 1:  batch loss at current step: 249.0790252685547
# Accuracy: 48.84%
# Epoch 78, CIFAR-10 Batch 1:  batch loss at current step: 252.09469604492188
# Accuracy: 48.98%
# Epoch 79, CIFAR-10 Batch 1:  batch loss at current step: 243.08782958984375
# Accuracy: 49.28%
# Epoch 80, CIFAR-10 Batch 1:  batch loss at current step: 265.105712890625
# Accuracy: 48.78%
# Epoch 81, CIFAR-10 Batch 1:  batch loss at current step: 248.21597290039062
# Accuracy: 48.74%
# Epoch 82, CIFAR-10 Batch 1:  batch loss at current step: 271.4071044921875
# Accuracy: 48.80%
# Epoch 83, CIFAR-10 Batch 1:  batch loss at current step: 263.0381164550781
# Accuracy: 49.08%
# Epoch 84, CIFAR-10 Batch 1:  batch loss at current step: 246.84007263183594
# Accuracy: 47.90%
# Epoch 85, CIFAR-10 Batch 1:  batch loss at current step: 259.4881591796875
# Accuracy: 48.62%
# Epoch 86, CIFAR-10 Batch 1:  batch loss at current step: 249.05677795410156
# Accuracy: 48.74%
# Epoch 87, CIFAR-10 Batch 1:  batch loss at current step: 249.4873046875
# Accuracy: 49.06%
# Epoch 88, CIFAR-10 Batch 1:  batch loss at current step: 272.5146484375
# Accuracy: 47.48%
# Epoch 89, CIFAR-10 Batch 1:  batch loss at current step: 244.41375732421875
# Accuracy: 49.90%
# Epoch 90, CIFAR-10 Batch 1:  batch loss at current step: 247.98597717285156
# Accuracy: 49.78%
# Epoch 91, CIFAR-10 Batch 1:  batch loss at current step: 251.39535522460938
# Accuracy: 48.06%
# Epoch 92, CIFAR-10 Batch 1:  batch loss at current step: 266.3526611328125
# Accuracy: 47.30%
# Epoch 93, CIFAR-10 Batch 1:  batch loss at current step: 253.3311767578125
# Accuracy: 48.80%
# Epoch 94, CIFAR-10 Batch 1:  batch loss at current step: 261.434814453125
# Accuracy: 48.34%
# Epoch 95, CIFAR-10 Batch 1:  batch loss at current step: 264.40167236328125
# Accuracy: 48.24%
# Epoch 96, CIFAR-10 Batch 1:  batch loss at current step: 275.2038269042969
# Accuracy: 48.62%
# Epoch 97, CIFAR-10 Batch 1:  batch loss at current step: 247.5478515625
# Accuracy: 50.64%
# Epoch 98, CIFAR-10 Batch 1:  batch loss at current step: 238.8511199951172
# Accuracy: 50.66%
# Epoch 99, CIFAR-10 Batch 1:  batch loss at current step: 263.0282897949219
# Accuracy: 49.06%
# Epoch 100, CIFAR-10 Batch 1:  batch loss at current step: 239.2053985595703
# Accuracy: 50.58%

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  batch loss at current step: 769.4431762695312
# Accuracy: 24.62%
# Epoch  1, CIFAR-10 Batch 2:  batch loss at current step: 558.8046264648438
# Accuracy: 28.96%
# Epoch  1, CIFAR-10 Batch 3:  batch loss at current step: 484.0126647949219
# Accuracy: 29.98%
# Epoch  1, CIFAR-10 Batch 4:  batch loss at current step: 414.6315612792969
# Accuracy: 32.94%
# Epoch  1, CIFAR-10 Batch 5:  batch loss at current step: 370.62139892578125
# Accuracy: 35.40%
# Epoch  2, CIFAR-10 Batch 1:  batch loss at current step: 322.51690673828125
# Accuracy: 37.24%
# Epoch  2, CIFAR-10 Batch 2:  batch loss at current step: 324.7197570800781
# Accuracy: 37.76%
# Epoch  2, CIFAR-10 Batch 3:  batch loss at current step: 317.81976318359375
# Accuracy: 34.96%
# Epoch  2, CIFAR-10 Batch 4:  batch loss at current step: 256.2333984375
# Accuracy: 40.86%
# Epoch  2, CIFAR-10 Batch 5:  batch loss at current step: 240.36654663085938
# Accuracy: 41.90%
# Epoch  3, CIFAR-10 Batch 1:  batch loss at current step: 226.71095275878906
# Accuracy: 42.62%
# Epoch  3, CIFAR-10 Batch 2:  batch loss at current step: 230.82530212402344
# Accuracy: 42.18%
# Epoch  3, CIFAR-10 Batch 3:  batch loss at current step: 221.8993682861328
# Accuracy: 40.30%
# Epoch  3, CIFAR-10 Batch 4:  batch loss at current step: 201.5107421875
# Accuracy: 43.88%
# Epoch  3, CIFAR-10 Batch 5:  batch loss at current step: 212.94009399414062
# Accuracy: 43.16%
# Epoch  4, CIFAR-10 Batch 1:  batch loss at current step: 189.09219360351562
# Accuracy: 44.94%
# Epoch  4, CIFAR-10 Batch 2:  batch loss at current step: 186.38961791992188
# Accuracy: 45.80%
# Epoch  4, CIFAR-10 Batch 3:  batch loss at current step: 184.52854919433594
# Accuracy: 44.18%
# Epoch  4, CIFAR-10 Batch 4:  batch loss at current step: 189.17718505859375
# Accuracy: 44.70%
# Epoch  4, CIFAR-10 Batch 5:  batch loss at current step: 179.10252380371094
# Accuracy: 45.96%
# Epoch  5, CIFAR-10 Batch 1:  batch loss at current step: 182.326904296875
# Accuracy: 45.38%
# Epoch  5, CIFAR-10 Batch 2:  batch loss at current step: 167.2576446533203
# Accuracy: 46.58%
# Epoch  5, CIFAR-10 Batch 3:  batch loss at current step: 181.77444458007812
# Accuracy: 44.78%
# Epoch  5, CIFAR-10 Batch 4:  batch loss at current step: 172.24673461914062
# Accuracy: 45.42%
# Epoch  5, CIFAR-10 Batch 5:  batch loss at current step: 173.48789978027344
# Accuracy: 45.96%
# Epoch  6, CIFAR-10 Batch 1:  batch loss at current step: 173.82179260253906
# Accuracy: 46.74%
# Epoch  6, CIFAR-10 Batch 2:  batch loss at current step: 144.83969116210938
# Accuracy: 49.44%
# Epoch  6, CIFAR-10 Batch 3:  batch loss at current step: 178.01065063476562
# Accuracy: 44.06%
# Epoch  6, CIFAR-10 Batch 4:  batch loss at current step: 159.17755126953125
# Accuracy: 46.58%
# Epoch  6, CIFAR-10 Batch 5:  batch loss at current step: 157.24844360351562
# Accuracy: 47.98%
# Epoch  7, CIFAR-10 Batch 1:  batch loss at current step: 157.18814086914062
# Accuracy: 48.30%
# Epoch  7, CIFAR-10 Batch 2:  batch loss at current step: 139.76173400878906
# Accuracy: 49.24%
# Epoch  7, CIFAR-10 Batch 3:  batch loss at current step: 146.1543426513672
# Accuracy: 47.14%
# Epoch  7, CIFAR-10 Batch 4:  batch loss at current step: 136.46470642089844
# Accuracy: 50.46%
# Epoch  7, CIFAR-10 Batch 5:  batch loss at current step: 150.30673217773438
# Accuracy: 49.38%
# Epoch  8, CIFAR-10 Batch 1:  batch loss at current step: 131.12985229492188
# Accuracy: 50.48%
# Epoch  8, CIFAR-10 Batch 2:  batch loss at current step: 141.40737915039062
# Accuracy: 48.66%
# Epoch  8, CIFAR-10 Batch 3:  batch loss at current step: 135.6636199951172
# Accuracy: 48.20%
# Epoch  8, CIFAR-10 Batch 4:  batch loss at current step: 131.1990203857422
# Accuracy: 51.34%
# Epoch  8, CIFAR-10 Batch 5:  batch loss at current step: 132.96490478515625
# Accuracy: 49.36%
# Epoch  9, CIFAR-10 Batch 1:  batch loss at current step: 122.94356536865234
# Accuracy: 51.54%
# Epoch  9, CIFAR-10 Batch 2:  batch loss at current step: 134.72752380371094
# Accuracy: 49.00%
# Epoch  9, CIFAR-10 Batch 3:  batch loss at current step: 125.54973602294922
# Accuracy: 49.56%
# Epoch  9, CIFAR-10 Batch 4:  batch loss at current step: 120.9477767944336
# Accuracy: 52.22%
# Epoch  9, CIFAR-10 Batch 5:  batch loss at current step: 132.7650909423828
# Accuracy: 48.98%
# Epoch 10, CIFAR-10 Batch 1:  batch loss at current step: 119.25992584228516
# Accuracy: 51.72%
# Epoch 10, CIFAR-10 Batch 2:  batch loss at current step: 114.82272338867188
# Accuracy: 50.56%
# Epoch 10, CIFAR-10 Batch 3:  batch loss at current step: 119.23463439941406
# Accuracy: 50.28%
# Epoch 10, CIFAR-10 Batch 4:  batch loss at current step: 117.06964874267578
# Accuracy: 51.14%
# Epoch 10, CIFAR-10 Batch 5:  batch loss at current step: 129.0876007080078
# Accuracy: 49.08%
# Epoch 11, CIFAR-10 Batch 1:  batch loss at current step: 114.98780059814453
# Accuracy: 52.50%
# Epoch 11, CIFAR-10 Batch 2:  batch loss at current step: 108.64552307128906
# Accuracy: 52.46%
# Epoch 11, CIFAR-10 Batch 3:  batch loss at current step: 117.51864624023438
# Accuracy: 50.64%
# Epoch 11, CIFAR-10 Batch 4:  batch loss at current step: 115.61612701416016
# Accuracy: 51.82%
# Epoch 11, CIFAR-10 Batch 5:  batch loss at current step: 122.17581176757812
# Accuracy: 49.74%
# Epoch 12, CIFAR-10 Batch 1:  batch loss at current step: 107.73286437988281
# Accuracy: 52.62%
# Epoch 12, CIFAR-10 Batch 2:  batch loss at current step: 111.48836517333984
# Accuracy: 51.58%
# Epoch 12, CIFAR-10 Batch 3:  batch loss at current step: 107.40121459960938
# Accuracy: 53.40%
# Epoch 12, CIFAR-10 Batch 4:  batch loss at current step: 108.72207641601562
# Accuracy: 54.08%
# Epoch 12, CIFAR-10 Batch 5:  batch loss at current step: 107.42057800292969
# Accuracy: 51.58%
# Epoch 13, CIFAR-10 Batch 1:  batch loss at current step: 101.88556671142578
# Accuracy: 54.26%
# Epoch 13, CIFAR-10 Batch 2:  batch loss at current step: 107.20487213134766
# Accuracy: 51.86%
# Epoch 13, CIFAR-10 Batch 3:  batch loss at current step: 104.56099700927734
# Accuracy: 53.82%
# Epoch 13, CIFAR-10 Batch 4:  batch loss at current step: 100.43355560302734
# Accuracy: 54.74%
# Epoch 13, CIFAR-10 Batch 5:  batch loss at current step: 99.92328643798828
# Accuracy: 53.82%
# Epoch 14, CIFAR-10 Batch 1:  batch loss at current step: 100.58621978759766
# Accuracy: 53.48%
# Epoch 14, CIFAR-10 Batch 2:  batch loss at current step: 102.8711166381836
# Accuracy: 52.42%
# Epoch 14, CIFAR-10 Batch 3:  batch loss at current step: 104.13027954101562
# Accuracy: 52.86%
# Epoch 14, CIFAR-10 Batch 4:  batch loss at current step: 102.0724868774414
# Accuracy: 54.26%
# Epoch 14, CIFAR-10 Batch 5:  batch loss at current step: 102.0604019165039
# Accuracy: 53.16%
# Epoch 15, CIFAR-10 Batch 1:  batch loss at current step: 105.53765106201172
# Accuracy: 51.76%
# Epoch 15, CIFAR-10 Batch 2:  batch loss at current step: 103.265380859375
# Accuracy: 51.66%
# Epoch 15, CIFAR-10 Batch 3:  batch loss at current step: 94.41323852539062
# Accuracy: 54.98%
# Epoch 15, CIFAR-10 Batch 4:  batch loss at current step: 98.33836364746094
# Accuracy: 54.28%
# Epoch 15, CIFAR-10 Batch 5:  batch loss at current step: 109.52007293701172
# Accuracy: 51.64%
# Epoch 16, CIFAR-10 Batch 1:  batch loss at current step: 103.85079193115234
# Accuracy: 53.02%
# Epoch 16, CIFAR-10 Batch 2:  batch loss at current step: 90.34463500976562
# Accuracy: 54.62%
# Epoch 16, CIFAR-10 Batch 3:  batch loss at current step: 94.78138732910156
# Accuracy: 54.98%
# Epoch 16, CIFAR-10 Batch 4:  batch loss at current step: 99.69145965576172
# Accuracy: 53.68%
# Epoch 16, CIFAR-10 Batch 5:  batch loss at current step: 102.01797485351562
# Accuracy: 52.76%
# Epoch 17, CIFAR-10 Batch 1:  batch loss at current step: 101.41777038574219
# Accuracy: 53.50%
# Epoch 17, CIFAR-10 Batch 2:  batch loss at current step: 88.25200653076172
# Accuracy: 55.00%
# Epoch 17, CIFAR-10 Batch 3:  batch loss at current step: 92.23011016845703
# Accuracy: 55.00%
# Epoch 17, CIFAR-10 Batch 4:  batch loss at current step: 95.69747161865234
# Accuracy: 52.80%
# Epoch 17, CIFAR-10 Batch 5:  batch loss at current step: 95.98836517333984
# Accuracy: 53.50%
# Epoch 18, CIFAR-10 Batch 1:  batch loss at current step: 97.30104064941406
# Accuracy: 53.62%
# Epoch 18, CIFAR-10 Batch 2:  batch loss at current step: 98.09852600097656
# Accuracy: 52.42%
# Epoch 18, CIFAR-10 Batch 3:  batch loss at current step: 94.20543670654297
# Accuracy: 53.76%
# Epoch 18, CIFAR-10 Batch 4:  batch loss at current step: 91.45863342285156
# Accuracy: 54.20%
# Epoch 18, CIFAR-10 Batch 5:  batch loss at current step: 87.04317474365234
# Accuracy: 54.86%
# Epoch 19, CIFAR-10 Batch 1:  batch loss at current step: 94.01300811767578
# Accuracy: 54.64%
# Epoch 19, CIFAR-10 Batch 2:  batch loss at current step: 102.55228424072266
# Accuracy: 50.70%
# Epoch 19, CIFAR-10 Batch 3:  batch loss at current step: 93.05630493164062
# Accuracy: 53.00%
# Epoch 19, CIFAR-10 Batch 4:  batch loss at current step: 89.03765869140625
# Accuracy: 54.10%
# Epoch 19, CIFAR-10 Batch 5:  batch loss at current step: 92.0323257446289
# Accuracy: 54.00%
# Epoch 20, CIFAR-10 Batch 1:  batch loss at current step: 88.17939758300781
# Accuracy: 55.88%
# Epoch 20, CIFAR-10 Batch 2:  batch loss at current step: 99.44637298583984
# Accuracy: 50.58%
# Epoch 20, CIFAR-10 Batch 3:  batch loss at current step: 93.15017700195312
# Accuracy: 53.20%
# Epoch 20, CIFAR-10 Batch 4:  batch loss at current step: 87.64402770996094
# Accuracy: 53.94%
# Epoch 20, CIFAR-10 Batch 5:  batch loss at current step: 85.44587707519531
# Accuracy: 55.62%
# Epoch 21, CIFAR-10 Batch 1:  batch loss at current step: 95.09992218017578
# Accuracy: 54.82%
# Epoch 21, CIFAR-10 Batch 2:  batch loss at current step: 85.37812042236328
# Accuracy: 54.56%
# Epoch 21, CIFAR-10 Batch 3:  batch loss at current step: 96.32442474365234
# Accuracy: 52.50%
# Epoch 21, CIFAR-10 Batch 4:  batch loss at current step: 91.86820983886719
# Accuracy: 54.44%
# Epoch 21, CIFAR-10 Batch 5:  batch loss at current step: 91.17999267578125
# Accuracy: 54.82%
# Epoch 22, CIFAR-10 Batch 1:  batch loss at current step: 88.39167022705078
# Accuracy: 54.96%
# Epoch 22, CIFAR-10 Batch 2:  batch loss at current step: 89.90771484375
# Accuracy: 54.00%
# Epoch 22, CIFAR-10 Batch 3:  batch loss at current step: 96.08094024658203
# Accuracy: 51.90%
# Epoch 22, CIFAR-10 Batch 4:  batch loss at current step: 93.1807632446289
# Accuracy: 55.06%
# Epoch 22, CIFAR-10 Batch 5:  batch loss at current step: 91.42745971679688
# Accuracy: 53.16%
# Epoch 23, CIFAR-10 Batch 1:  batch loss at current step: 89.18775177001953
# Accuracy: 54.44%
# Epoch 23, CIFAR-10 Batch 2:  batch loss at current step: 92.8589096069336
# Accuracy: 54.36%
# Epoch 23, CIFAR-10 Batch 3:  batch loss at current step: 88.9511489868164
# Accuracy: 53.66%
# Epoch 23, CIFAR-10 Batch 4:  batch loss at current step: 102.68310546875
# Accuracy: 51.96%
# Epoch 23, CIFAR-10 Batch 5:  batch loss at current step: 89.47173309326172
# Accuracy: 52.92%
# Epoch 24, CIFAR-10 Batch 1:  batch loss at current step: 87.4211654663086
# Accuracy: 55.02%
# Epoch 24, CIFAR-10 Batch 2:  batch loss at current step: 96.04194641113281
# Accuracy: 53.74%
# Epoch 24, CIFAR-10 Batch 3:  batch loss at current step: 82.93415069580078
# Accuracy: 54.76%
# Epoch 24, CIFAR-10 Batch 4:  batch loss at current step: 99.35533142089844
# Accuracy: 52.56%
# Epoch 24, CIFAR-10 Batch 5:  batch loss at current step: 94.8499984741211
# Accuracy: 52.44%
# Epoch 25, CIFAR-10 Batch 1:  batch loss at current step: 85.66400146484375
# Accuracy: 55.14%
# Epoch 25, CIFAR-10 Batch 2:  batch loss at current step: 90.45893096923828
# Accuracy: 53.80%
# Epoch 25, CIFAR-10 Batch 3:  batch loss at current step: 85.16278839111328
# Accuracy: 54.76%
# Epoch 25, CIFAR-10 Batch 4:  batch loss at current step: 90.66827392578125
# Accuracy: 54.06%
# Epoch 25, CIFAR-10 Batch 5:  batch loss at current step: 95.8957748413086
# Accuracy: 52.34%
# Epoch 26, CIFAR-10 Batch 1:  batch loss at current step: 87.70870208740234
# Accuracy: 54.64%
# Epoch 26, CIFAR-10 Batch 2:  batch loss at current step: 92.02128601074219
# Accuracy: 54.16%
# Epoch 26, CIFAR-10 Batch 3:  batch loss at current step: 83.75379943847656
# Accuracy: 55.68%
# Epoch 26, CIFAR-10 Batch 4:  batch loss at current step: 82.8565444946289
# Accuracy: 55.46%
# Epoch 26, CIFAR-10 Batch 5:  batch loss at current step: 81.17098999023438
# Accuracy: 56.22%
# Epoch 27, CIFAR-10 Batch 1:  batch loss at current step: 91.21536254882812
# Accuracy: 53.10%
# Epoch 27, CIFAR-10 Batch 2:  batch loss at current step: 96.04469299316406
# Accuracy: 51.86%
# Epoch 27, CIFAR-10 Batch 3:  batch loss at current step: 88.49722290039062
# Accuracy: 53.58%
# Epoch 27, CIFAR-10 Batch 4:  batch loss at current step: 87.32976531982422
# Accuracy: 54.34%
# Epoch 27, CIFAR-10 Batch 5:  batch loss at current step: 80.65652465820312
# Accuracy: 56.84%
# Epoch 28, CIFAR-10 Batch 1:  batch loss at current step: 94.46504211425781
# Accuracy: 52.44%
# Epoch 28, CIFAR-10 Batch 2:  batch loss at current step: 84.83470916748047
# Accuracy: 54.58%
# Epoch 28, CIFAR-10 Batch 3:  batch loss at current step: 81.8248519897461
# Accuracy: 54.78%
# Epoch 28, CIFAR-10 Batch 4:  batch loss at current step: 91.1224365234375
# Accuracy: 54.94%
# Epoch 28, CIFAR-10 Batch 5:  batch loss at current step: 79.8067626953125
# Accuracy: 56.58%
# Epoch 29, CIFAR-10 Batch 1:  batch loss at current step: 88.0699234008789
# Accuracy: 54.18%
# Epoch 29, CIFAR-10 Batch 2:  batch loss at current step: 82.48181915283203
# Accuracy: 55.14%
# Epoch 29, CIFAR-10 Batch 3:  batch loss at current step: 86.2134780883789
# Accuracy: 53.90%
# Epoch 29, CIFAR-10 Batch 4:  batch loss at current step: 85.36427307128906
# Accuracy: 55.40%
# Epoch 29, CIFAR-10 Batch 5:  batch loss at current step: 78.93181610107422
# Accuracy: 57.30%
# Epoch 30, CIFAR-10 Batch 1:  batch loss at current step: 82.85952758789062
# Accuracy: 56.58%
# Epoch 30, CIFAR-10 Batch 2:  batch loss at current step: 82.34061431884766
# Accuracy: 55.52%
# Epoch 30, CIFAR-10 Batch 3:  batch loss at current step: 86.7652587890625
# Accuracy: 54.56%
# Epoch 30, CIFAR-10 Batch 4:  batch loss at current step: 86.36285400390625
# Accuracy: 54.48%
# Epoch 30, CIFAR-10 Batch 5:  batch loss at current step: 75.50421142578125
# Accuracy: 58.32%
# Epoch 31, CIFAR-10 Batch 1:  batch loss at current step: 80.82520294189453
# Accuracy: 56.70%
# Epoch 31, CIFAR-10 Batch 2:  batch loss at current step: 81.41028594970703
# Accuracy: 54.84%
# Epoch 31, CIFAR-10 Batch 3:  batch loss at current step: 83.35667419433594
# Accuracy: 56.02%
# Epoch 31, CIFAR-10 Batch 4:  batch loss at current step: 82.33061218261719
# Accuracy: 55.64%
# Epoch 31, CIFAR-10 Batch 5:  batch loss at current step: 76.74999237060547
# Accuracy: 57.60%
# Epoch 32, CIFAR-10 Batch 1:  batch loss at current step: 81.67083740234375
# Accuracy: 55.64%
# Epoch 32, CIFAR-10 Batch 2:  batch loss at current step: 80.04962158203125
# Accuracy: 56.06%
# Epoch 32, CIFAR-10 Batch 3:  batch loss at current step: 84.2083511352539
# Accuracy: 55.82%
# Epoch 32, CIFAR-10 Batch 4:  batch loss at current step: 81.22789764404297
# Accuracy: 55.86%
# Epoch 32, CIFAR-10 Batch 5:  batch loss at current step: 81.75037384033203
# Accuracy: 56.64%
# Epoch 33, CIFAR-10 Batch 1:  batch loss at current step: 80.59909057617188
# Accuracy: 56.54%
# Epoch 33, CIFAR-10 Batch 2:  batch loss at current step: 82.8167724609375
# Accuracy: 54.78%
# Epoch 33, CIFAR-10 Batch 3:  batch loss at current step: 82.8593978881836
# Accuracy: 55.94%
# Epoch 33, CIFAR-10 Batch 4:  batch loss at current step: 81.38383483886719
# Accuracy: 55.28%
# Epoch 33, CIFAR-10 Batch 5:  batch loss at current step: 81.10355377197266
# Accuracy: 56.90%
# Epoch 34, CIFAR-10 Batch 1:  batch loss at current step: 82.35304260253906
# Accuracy: 55.46%
# Epoch 34, CIFAR-10 Batch 2:  batch loss at current step: 82.31549072265625
# Accuracy: 55.58%
# Epoch 34, CIFAR-10 Batch 3:  batch loss at current step: 80.86433410644531
# Accuracy: 56.42%
# Epoch 34, CIFAR-10 Batch 4:  batch loss at current step: 80.49845123291016
# Accuracy: 55.56%
# Epoch 34, CIFAR-10 Batch 5:  batch loss at current step: 79.0160903930664
# Accuracy: 58.12%
# Epoch 35, CIFAR-10 Batch 1:  batch loss at current step: 84.41864776611328
# Accuracy: 55.00%
# Epoch 35, CIFAR-10 Batch 2:  batch loss at current step: 81.08898162841797
# Accuracy: 56.06%
# Epoch 35, CIFAR-10 Batch 3:  batch loss at current step: 79.79419708251953
# Accuracy: 56.86%
# Epoch 35, CIFAR-10 Batch 4:  batch loss at current step: 84.96478271484375
# Accuracy: 54.52%
# Epoch 35, CIFAR-10 Batch 5:  batch loss at current step: 78.50457763671875
# Accuracy: 58.04%
# Epoch 36, CIFAR-10 Batch 1:  batch loss at current step: 78.27645111083984
# Accuracy: 56.18%
# Epoch 36, CIFAR-10 Batch 2:  batch loss at current step: 78.98056030273438
# Accuracy: 56.02%
# Epoch 36, CIFAR-10 Batch 3:  batch loss at current step: 79.92761993408203
# Accuracy: 57.56%
# Epoch 36, CIFAR-10 Batch 4:  batch loss at current step: 84.96749114990234
# Accuracy: 54.40%
# Epoch 36, CIFAR-10 Batch 5:  batch loss at current step: 77.79335021972656
# Accuracy: 57.64%
# Epoch 37, CIFAR-10 Batch 1:  batch loss at current step: 75.91453552246094
# Accuracy: 57.82%
# Epoch 37, CIFAR-10 Batch 2:  batch loss at current step: 83.91130065917969
# Accuracy: 54.88%
# Epoch 37, CIFAR-10 Batch 3:  batch loss at current step: 77.06158447265625
# Accuracy: 57.62%
# Epoch 37, CIFAR-10 Batch 4:  batch loss at current step: 87.00372314453125
# Accuracy: 54.22%
# Epoch 37, CIFAR-10 Batch 5:  batch loss at current step: 73.2996597290039
# Accuracy: 58.52%
# Epoch 38, CIFAR-10 Batch 1:  batch loss at current step: 82.25581359863281
# Accuracy: 55.58%
# Epoch 38, CIFAR-10 Batch 2:  batch loss at current step: 89.13124084472656
# Accuracy: 53.32%
# Epoch 38, CIFAR-10 Batch 3:  batch loss at current step: 78.035400390625
# Accuracy: 57.00%
# Epoch 38, CIFAR-10 Batch 4:  batch loss at current step: 78.54273986816406
# Accuracy: 56.28%
# Epoch 38, CIFAR-10 Batch 5:  batch loss at current step: 74.27582550048828
# Accuracy: 57.80%
# Epoch 39, CIFAR-10 Batch 1:  batch loss at current step: 78.54052734375
# Accuracy: 56.78%
# Epoch 39, CIFAR-10 Batch 2:  batch loss at current step: 85.36414337158203
# Accuracy: 54.38%
# Epoch 39, CIFAR-10 Batch 3:  batch loss at current step: 77.72026062011719
# Accuracy: 57.86%
# Epoch 39, CIFAR-10 Batch 4:  batch loss at current step: 74.4152603149414
# Accuracy: 57.78%
# Epoch 39, CIFAR-10 Batch 5:  batch loss at current step: 80.32803344726562
# Accuracy: 57.40%
# Epoch 40, CIFAR-10 Batch 1:  batch loss at current step: 80.86643981933594
# Accuracy: 56.74%
# Epoch 40, CIFAR-10 Batch 2:  batch loss at current step: 81.71248626708984
# Accuracy: 56.06%
# Epoch 40, CIFAR-10 Batch 3:  batch loss at current step: 80.86821746826172
# Accuracy: 56.16%
# Epoch 40, CIFAR-10 Batch 4:  batch loss at current step: 76.47431182861328
# Accuracy: 57.36%
# Epoch 40, CIFAR-10 Batch 5:  batch loss at current step: 77.96534729003906
# Accuracy: 57.36%
# Epoch 41, CIFAR-10 Batch 1:  batch loss at current step: 79.05364990234375
# Accuracy: 56.82%
# Epoch 41, CIFAR-10 Batch 2:  batch loss at current step: 80.44715881347656
# Accuracy: 56.10%
# Epoch 41, CIFAR-10 Batch 3:  batch loss at current step: 82.24232482910156
# Accuracy: 56.24%
# Epoch 41, CIFAR-10 Batch 4:  batch loss at current step: 77.10195922851562
# Accuracy: 57.44%
# Epoch 41, CIFAR-10 Batch 5:  batch loss at current step: 76.26727294921875
# Accuracy: 57.90%
# Epoch 42, CIFAR-10 Batch 1:  batch loss at current step: 73.21800994873047
# Accuracy: 58.32%
# Epoch 42, CIFAR-10 Batch 2:  batch loss at current step: 80.82149505615234
# Accuracy: 55.52%
# Epoch 42, CIFAR-10 Batch 3:  batch loss at current step: 78.19547271728516
# Accuracy: 56.82%
# Epoch 42, CIFAR-10 Batch 4:  batch loss at current step: 77.6659927368164
# Accuracy: 57.46%
# Epoch 42, CIFAR-10 Batch 5:  batch loss at current step: 74.75582122802734
# Accuracy: 57.86%
# Epoch 43, CIFAR-10 Batch 1:  batch loss at current step: 74.91511535644531
# Accuracy: 58.40%
# Epoch 43, CIFAR-10 Batch 2:  batch loss at current step: 78.78298950195312
# Accuracy: 56.40%
# Epoch 43, CIFAR-10 Batch 3:  batch loss at current step: 77.56693267822266
# Accuracy: 57.48%
# Epoch 43, CIFAR-10 Batch 4:  batch loss at current step: 74.35136413574219
# Accuracy: 57.14%
# Epoch 43, CIFAR-10 Batch 5:  batch loss at current step: 72.3115234375
# Accuracy: 58.58%
# Epoch 44, CIFAR-10 Batch 1:  batch loss at current step: 74.2171859741211
# Accuracy: 58.14%
# Epoch 44, CIFAR-10 Batch 2:  batch loss at current step: 77.50287628173828
# Accuracy: 56.42%
# Epoch 44, CIFAR-10 Batch 3:  batch loss at current step: 76.64029693603516
# Accuracy: 58.48%
# Epoch 44, CIFAR-10 Batch 4:  batch loss at current step: 75.69294738769531
# Accuracy: 57.74%
# Epoch 44, CIFAR-10 Batch 5:  batch loss at current step: 76.1695785522461
# Accuracy: 58.18%
# Epoch 45, CIFAR-10 Batch 1:  batch loss at current step: 75.01384735107422
# Accuracy: 58.50%
# Epoch 45, CIFAR-10 Batch 2:  batch loss at current step: 80.49410247802734
# Accuracy: 54.96%
# Epoch 45, CIFAR-10 Batch 3:  batch loss at current step: 75.8077163696289
# Accuracy: 57.80%
# Epoch 45, CIFAR-10 Batch 4:  batch loss at current step: 74.81275177001953
# Accuracy: 57.32%
# Epoch 45, CIFAR-10 Batch 5:  batch loss at current step: 73.72634887695312
# Accuracy: 58.44%
# Epoch 46, CIFAR-10 Batch 1:  batch loss at current step: 74.6590576171875
# Accuracy: 58.24%
# Epoch 46, CIFAR-10 Batch 2:  batch loss at current step: 79.63707733154297
# Accuracy: 55.50%
# Epoch 46, CIFAR-10 Batch 3:  batch loss at current step: 72.41292572021484
# Accuracy: 58.26%
# Epoch 46, CIFAR-10 Batch 4:  batch loss at current step: 73.64563751220703
# Accuracy: 56.80%
# Epoch 46, CIFAR-10 Batch 5:  batch loss at current step: 72.41143035888672
# Accuracy: 58.60%
# Epoch 47, CIFAR-10 Batch 1:  batch loss at current step: 82.65779876708984
# Accuracy: 57.36%
# Epoch 47, CIFAR-10 Batch 2:  batch loss at current step: 73.18951416015625
# Accuracy: 57.72%
# Epoch 47, CIFAR-10 Batch 3:  batch loss at current step: 80.7636489868164
# Accuracy: 56.68%
# Epoch 47, CIFAR-10 Batch 4:  batch loss at current step: 71.89604949951172
# Accuracy: 58.34%
# Epoch 47, CIFAR-10 Batch 5:  batch loss at current step: 71.91815185546875
# Accuracy: 58.52%
# Epoch 48, CIFAR-10 Batch 1:  batch loss at current step: 80.03427124023438
# Accuracy: 58.04%
# Epoch 48, CIFAR-10 Batch 2:  batch loss at current step: 72.37774658203125
# Accuracy: 57.52%
# Epoch 48, CIFAR-10 Batch 3:  batch loss at current step: 82.36591339111328
# Accuracy: 55.68%
# Epoch 48, CIFAR-10 Batch 4:  batch loss at current step: 74.16143798828125
# Accuracy: 57.88%
# Epoch 48, CIFAR-10 Batch 5:  batch loss at current step: 72.32341003417969
# Accuracy: 58.46%
# Epoch 49, CIFAR-10 Batch 1:  batch loss at current step: 87.07742309570312
# Accuracy: 56.78%
# Epoch 49, CIFAR-10 Batch 2:  batch loss at current step: 72.75115966796875
# Accuracy: 58.34%
# Epoch 49, CIFAR-10 Batch 3:  batch loss at current step: 73.8918228149414
# Accuracy: 57.58%
# Epoch 49, CIFAR-10 Batch 4:  batch loss at current step: 75.7871322631836
# Accuracy: 57.64%
# Epoch 49, CIFAR-10 Batch 5:  batch loss at current step: 70.01807403564453
# Accuracy: 59.50%
# Epoch 50, CIFAR-10 Batch 1:  batch loss at current step: 78.00350952148438
# Accuracy: 58.50%
# Epoch 50, CIFAR-10 Batch 2:  batch loss at current step: 73.30511474609375
# Accuracy: 58.38%
# Epoch 50, CIFAR-10 Batch 3:  batch loss at current step: 75.17886352539062
# Accuracy: 57.58%
# Epoch 50, CIFAR-10 Batch 4:  batch loss at current step: 73.75566101074219
# Accuracy: 58.46%
# Epoch 50, CIFAR-10 Batch 5:  batch loss at current step: 74.22140502929688
# Accuracy: 58.08%
# Epoch 51, CIFAR-10 Batch 1:  batch loss at current step: 83.40505981445312
# Accuracy: 57.32%
# Epoch 51, CIFAR-10 Batch 2:  batch loss at current step: 72.12805938720703
# Accuracy: 58.66%
# Epoch 51, CIFAR-10 Batch 3:  batch loss at current step: 71.94300842285156
# Accuracy: 59.06%
# Epoch 51, CIFAR-10 Batch 4:  batch loss at current step: 74.19038391113281
# Accuracy: 58.32%
# Epoch 51, CIFAR-10 Batch 5:  batch loss at current step: 71.8471908569336
# Accuracy: 58.72%
# Epoch 52, CIFAR-10 Batch 1:  batch loss at current step: 77.65430450439453
# Accuracy: 59.32%
# Epoch 52, CIFAR-10 Batch 2:  batch loss at current step: 72.44940948486328
# Accuracy: 58.78%
# Epoch 52, CIFAR-10 Batch 3:  batch loss at current step: 70.73735809326172
# Accuracy: 59.28%
# Epoch 52, CIFAR-10 Batch 4:  batch loss at current step: 75.45635223388672
# Accuracy: 58.34%
# Epoch 52, CIFAR-10 Batch 5:  batch loss at current step: 70.67697143554688
# Accuracy: 59.42%
# Epoch 53, CIFAR-10 Batch 1:  batch loss at current step: 74.93885040283203
# Accuracy: 58.92%
# Epoch 53, CIFAR-10 Batch 2:  batch loss at current step: 71.48588562011719
# Accuracy: 58.94%
# Epoch 53, CIFAR-10 Batch 3:  batch loss at current step: 70.4745101928711
# Accuracy: 58.96%
# Epoch 53, CIFAR-10 Batch 4:  batch loss at current step: 74.09832000732422
# Accuracy: 59.14%
# Epoch 53, CIFAR-10 Batch 5:  batch loss at current step: 72.15827178955078
# Accuracy: 58.72%
# Epoch 54, CIFAR-10 Batch 1:  batch loss at current step: 71.1148910522461
# Accuracy: 59.16%
# Epoch 54, CIFAR-10 Batch 2:  batch loss at current step: 70.63272857666016
# Accuracy: 58.96%
# Epoch 54, CIFAR-10 Batch 3:  batch loss at current step: 77.30799865722656
# Accuracy: 57.62%
# Epoch 54, CIFAR-10 Batch 4:  batch loss at current step: 73.91169738769531
# Accuracy: 58.24%
# Epoch 54, CIFAR-10 Batch 5:  batch loss at current step: 72.60469818115234
# Accuracy: 58.28%
# Epoch 55, CIFAR-10 Batch 1:  batch loss at current step: 73.11041259765625
# Accuracy: 59.26%
# Epoch 55, CIFAR-10 Batch 2:  batch loss at current step: 71.10807800292969
# Accuracy: 59.36%
# Epoch 55, CIFAR-10 Batch 3:  batch loss at current step: 73.80635070800781
# Accuracy: 57.68%
# Epoch 55, CIFAR-10 Batch 4:  batch loss at current step: 73.36639404296875
# Accuracy: 58.74%
# Epoch 55, CIFAR-10 Batch 5:  batch loss at current step: 69.90315246582031
# Accuracy: 59.52%
# Epoch 56, CIFAR-10 Batch 1:  batch loss at current step: 71.97077941894531
# Accuracy: 60.02%
# Epoch 56, CIFAR-10 Batch 2:  batch loss at current step: 70.6626968383789
# Accuracy: 59.38%
# Epoch 56, CIFAR-10 Batch 3:  batch loss at current step: 72.28712463378906
# Accuracy: 59.16%
# Epoch 56, CIFAR-10 Batch 4:  batch loss at current step: 73.97675323486328
# Accuracy: 59.40%
# Epoch 56, CIFAR-10 Batch 5:  batch loss at current step: 71.25273895263672
# Accuracy: 60.08%
# Epoch 57, CIFAR-10 Batch 1:  batch loss at current step: 72.29717254638672
# Accuracy: 58.88%
# Epoch 57, CIFAR-10 Batch 2:  batch loss at current step: 72.39514923095703
# Accuracy: 59.42%
# Epoch 57, CIFAR-10 Batch 3:  batch loss at current step: 70.05610656738281
# Accuracy: 60.32%
# Epoch 57, CIFAR-10 Batch 4:  batch loss at current step: 73.60053253173828
# Accuracy: 59.92%
# Epoch 57, CIFAR-10 Batch 5:  batch loss at current step: 74.84376525878906
# Accuracy: 58.74%
# Epoch 58, CIFAR-10 Batch 1:  batch loss at current step: 76.42559051513672
# Accuracy: 58.80%
# Epoch 58, CIFAR-10 Batch 2:  batch loss at current step: 71.16470336914062
# Accuracy: 59.98%
# Epoch 58, CIFAR-10 Batch 3:  batch loss at current step: 71.30911254882812
# Accuracy: 59.14%
# Epoch 58, CIFAR-10 Batch 4:  batch loss at current step: 72.63528442382812
# Accuracy: 59.12%
# Epoch 58, CIFAR-10 Batch 5:  batch loss at current step: 71.05498504638672
# Accuracy: 59.22%
# Epoch 59, CIFAR-10 Batch 1:  batch loss at current step: 71.7397689819336
# Accuracy: 58.88%
# Epoch 59, CIFAR-10 Batch 2:  batch loss at current step: 70.34881591796875
# Accuracy: 59.92%
# Epoch 59, CIFAR-10 Batch 3:  batch loss at current step: 71.04069519042969
# Accuracy: 59.58%
# Epoch 59, CIFAR-10 Batch 4:  batch loss at current step: 77.3143539428711
# Accuracy: 58.16%
# Epoch 59, CIFAR-10 Batch 5:  batch loss at current step: 73.47631072998047
# Accuracy: 58.24%
# Epoch 60, CIFAR-10 Batch 1:  batch loss at current step: 76.84283447265625
# Accuracy: 58.42%
# Epoch 60, CIFAR-10 Batch 2:  batch loss at current step: 74.51453399658203
# Accuracy: 59.20%
# Epoch 60, CIFAR-10 Batch 3:  batch loss at current step: 71.9610595703125
# Accuracy: 59.96%
# Epoch 60, CIFAR-10 Batch 4:  batch loss at current step: 73.95652770996094
# Accuracy: 59.08%
# Epoch 60, CIFAR-10 Batch 5:  batch loss at current step: 73.19501495361328
# Accuracy: 58.90%
# Epoch 61, CIFAR-10 Batch 1:  batch loss at current step: 70.25230407714844
# Accuracy: 59.38%
# Epoch 61, CIFAR-10 Batch 2:  batch loss at current step: 69.84496307373047
# Accuracy: 59.62%
# Epoch 61, CIFAR-10 Batch 3:  batch loss at current step: 70.39315032958984
# Accuracy: 59.50%
# Epoch 61, CIFAR-10 Batch 4:  batch loss at current step: 71.37895202636719
# Accuracy: 59.96%
# Epoch 61, CIFAR-10 Batch 5:  batch loss at current step: 70.35198211669922
# Accuracy: 59.66%
# Epoch 62, CIFAR-10 Batch 1:  batch loss at current step: 74.90654754638672
# Accuracy: 57.78%
# Epoch 62, CIFAR-10 Batch 2:  batch loss at current step: 69.93035125732422
# Accuracy: 59.78%
# Epoch 62, CIFAR-10 Batch 3:  batch loss at current step: 72.50109100341797
# Accuracy: 59.72%
# Epoch 62, CIFAR-10 Batch 4:  batch loss at current step: 72.0811538696289
# Accuracy: 58.72%
# Epoch 62, CIFAR-10 Batch 5:  batch loss at current step: 71.32518005371094
# Accuracy: 58.78%
# Epoch 63, CIFAR-10 Batch 1:  batch loss at current step: 70.69985961914062
# Accuracy: 59.30%
# Epoch 63, CIFAR-10 Batch 2:  batch loss at current step: 75.24165344238281
# Accuracy: 58.56%
# Epoch 63, CIFAR-10 Batch 3:  batch loss at current step: 72.57302856445312
# Accuracy: 59.62%
# Epoch 63, CIFAR-10 Batch 4:  batch loss at current step: 73.47541809082031
# Accuracy: 58.30%
# Epoch 63, CIFAR-10 Batch 5:  batch loss at current step: 70.90648651123047
# Accuracy: 59.52%
# Epoch 64, CIFAR-10 Batch 1:  batch loss at current step: 70.83650207519531
# Accuracy: 58.12%
# Epoch 64, CIFAR-10 Batch 2:  batch loss at current step: 69.89014434814453
# Accuracy: 59.34%
# Epoch 64, CIFAR-10 Batch 3:  batch loss at current step: 72.33682250976562
# Accuracy: 59.34%
# Epoch 64, CIFAR-10 Batch 4:  batch loss at current step: 71.066162109375
# Accuracy: 58.94%
# Epoch 64, CIFAR-10 Batch 5:  batch loss at current step: 72.59522247314453
# Accuracy: 58.92%
# Epoch 65, CIFAR-10 Batch 1:  batch loss at current step: 72.81550598144531
# Accuracy: 58.58%
# Epoch 65, CIFAR-10 Batch 2:  batch loss at current step: 71.49969482421875
# Accuracy: 59.60%
# Epoch 65, CIFAR-10 Batch 3:  batch loss at current step: 71.06977844238281
# Accuracy: 59.52%
# Epoch 65, CIFAR-10 Batch 4:  batch loss at current step: 72.315185546875
# Accuracy: 59.44%
# Epoch 65, CIFAR-10 Batch 5:  batch loss at current step: 74.96019744873047
# Accuracy: 57.56%
# Epoch 66, CIFAR-10 Batch 1:  batch loss at current step: 69.81690979003906
# Accuracy: 59.64%
# Epoch 66, CIFAR-10 Batch 2:  batch loss at current step: 69.91114044189453
# Accuracy: 58.94%
# Epoch 66, CIFAR-10 Batch 3:  batch loss at current step: 70.5926284790039
# Accuracy: 59.42%
# Epoch 66, CIFAR-10 Batch 4:  batch loss at current step: 71.48179626464844
# Accuracy: 58.68%
# Epoch 66, CIFAR-10 Batch 5:  batch loss at current step: 69.86212158203125
# Accuracy: 59.10%
# Epoch 67, CIFAR-10 Batch 1:  batch loss at current step: 69.76322174072266
# Accuracy: 59.94%
# Epoch 67, CIFAR-10 Batch 2:  batch loss at current step: 69.8667984008789
# Accuracy: 59.40%
# Epoch 67, CIFAR-10 Batch 3:  batch loss at current step: 69.59331512451172
# Accuracy: 60.48%
# Epoch 67, CIFAR-10 Batch 4:  batch loss at current step: 70.94190216064453
# Accuracy: 58.94%
# Epoch 67, CIFAR-10 Batch 5:  batch loss at current step: 70.16812133789062
# Accuracy: 59.66%
# Epoch 68, CIFAR-10 Batch 1:  batch loss at current step: 67.79478454589844
# Accuracy: 60.34%
# Epoch 68, CIFAR-10 Batch 2:  batch loss at current step: 68.70891571044922
# Accuracy: 60.08%
# Epoch 68, CIFAR-10 Batch 3:  batch loss at current step: 70.0621337890625
# Accuracy: 60.32%
# Epoch 68, CIFAR-10 Batch 4:  batch loss at current step: 72.1192855834961
# Accuracy: 59.50%
# Epoch 68, CIFAR-10 Batch 5:  batch loss at current step: 70.2904052734375
# Accuracy: 59.46%
# Epoch 69, CIFAR-10 Batch 1:  batch loss at current step: 70.509765625
# Accuracy: 59.80%
# Epoch 69, CIFAR-10 Batch 2:  batch loss at current step: 68.81856536865234
# Accuracy: 59.30%
# Epoch 69, CIFAR-10 Batch 3:  batch loss at current step: 70.86759185791016
# Accuracy: 60.04%
# Epoch 69, CIFAR-10 Batch 4:  batch loss at current step: 72.25531005859375
# Accuracy: 59.38%
# Epoch 69, CIFAR-10 Batch 5:  batch loss at current step: 77.03032684326172
# Accuracy: 58.60%
# Epoch 70, CIFAR-10 Batch 1:  batch loss at current step: 71.77516174316406
# Accuracy: 59.50%
# Epoch 70, CIFAR-10 Batch 2:  batch loss at current step: 68.83501434326172
# Accuracy: 60.22%
# Epoch 70, CIFAR-10 Batch 3:  batch loss at current step: 71.1363754272461
# Accuracy: 59.78%
# Epoch 70, CIFAR-10 Batch 4:  batch loss at current step: 72.39262390136719
# Accuracy: 58.26%
# Epoch 70, CIFAR-10 Batch 5:  batch loss at current step: 72.82135009765625
# Accuracy: 58.52%
# Epoch 71, CIFAR-10 Batch 1:  batch loss at current step: 70.08515167236328
# Accuracy: 59.40%
# Epoch 71, CIFAR-10 Batch 2:  batch loss at current step: 68.82023620605469
# Accuracy: 59.96%
# Epoch 71, CIFAR-10 Batch 3:  batch loss at current step: 67.4388656616211
# Accuracy: 60.12%
# Epoch 71, CIFAR-10 Batch 4:  batch loss at current step: 71.30225372314453
# Accuracy: 58.54%
# Epoch 71, CIFAR-10 Batch 5:  batch loss at current step: 69.5673599243164
# Accuracy: 59.80%
# Epoch 72, CIFAR-10 Batch 1:  batch loss at current step: 69.76605224609375
# Accuracy: 59.44%
# Epoch 72, CIFAR-10 Batch 2:  batch loss at current step: 70.13754272460938
# Accuracy: 60.20%
# Epoch 72, CIFAR-10 Batch 3:  batch loss at current step: 69.57301330566406
# Accuracy: 60.22%
# Epoch 72, CIFAR-10 Batch 4:  batch loss at current step: 71.2623519897461
# Accuracy: 58.82%
# Epoch 72, CIFAR-10 Batch 5:  batch loss at current step: 70.53289794921875
# Accuracy: 59.04%
# Epoch 73, CIFAR-10 Batch 1:  batch loss at current step: 70.24714660644531
# Accuracy: 59.06%
# Epoch 73, CIFAR-10 Batch 2:  batch loss at current step: 68.30363464355469
# Accuracy: 59.92%
# Epoch 73, CIFAR-10 Batch 3:  batch loss at current step: 71.12487030029297
# Accuracy: 59.24%
# Epoch 73, CIFAR-10 Batch 4:  batch loss at current step: 69.14724731445312
# Accuracy: 59.50%
# Epoch 73, CIFAR-10 Batch 5:  batch loss at current step: 71.35310363769531
# Accuracy: 58.96%
# Epoch 74, CIFAR-10 Batch 1:  batch loss at current step: 72.9207534790039
# Accuracy: 57.40%
# Epoch 74, CIFAR-10 Batch 2:  batch loss at current step: 67.19692993164062
# Accuracy: 59.94%
# Epoch 74, CIFAR-10 Batch 3:  batch loss at current step: 67.57503509521484
# Accuracy: 59.60%
# Epoch 74, CIFAR-10 Batch 4:  batch loss at current step: 69.57359313964844
# Accuracy: 58.50%
# Epoch 74, CIFAR-10 Batch 5:  batch loss at current step: 67.1556167602539
# Accuracy: 60.12%
# Epoch 75, CIFAR-10 Batch 1:  batch loss at current step: 69.0721435546875
# Accuracy: 59.22%
# Epoch 75, CIFAR-10 Batch 2:  batch loss at current step: 68.33006286621094
# Accuracy: 58.74%
# Epoch 75, CIFAR-10 Batch 3:  batch loss at current step: 69.83243560791016
# Accuracy: 59.68%
# Epoch 75, CIFAR-10 Batch 4:  batch loss at current step: 67.29679870605469
# Accuracy: 59.50%
# Epoch 75, CIFAR-10 Batch 5:  batch loss at current step: 67.96060180664062
# Accuracy: 59.66%
# Epoch 76, CIFAR-10 Batch 1:  batch loss at current step: 69.4216079711914
# Accuracy: 58.18%
# Epoch 76, CIFAR-10 Batch 2:  batch loss at current step: 67.9786148071289
# Accuracy: 59.56%
# Epoch 76, CIFAR-10 Batch 3:  batch loss at current step: 69.42727661132812
# Accuracy: 59.16%
# Epoch 76, CIFAR-10 Batch 4:  batch loss at current step: 68.47748565673828
# Accuracy: 58.52%
# Epoch 76, CIFAR-10 Batch 5:  batch loss at current step: 67.9506607055664
# Accuracy: 60.28%
# Epoch 77, CIFAR-10 Batch 1:  batch loss at current step: 71.59103393554688
# Accuracy: 58.88%
# Epoch 77, CIFAR-10 Batch 2:  batch loss at current step: 69.14215087890625
# Accuracy: 59.56%
# Epoch 77, CIFAR-10 Batch 3:  batch loss at current step: 68.18733978271484
# Accuracy: 59.84%
# Epoch 77, CIFAR-10 Batch 4:  batch loss at current step: 70.44666290283203
# Accuracy: 59.30%
# Epoch 77, CIFAR-10 Batch 5:  batch loss at current step: 69.61267852783203
# Accuracy: 59.80%
# Epoch 78, CIFAR-10 Batch 1:  batch loss at current step: 70.62467193603516
# Accuracy: 58.64%
# Epoch 78, CIFAR-10 Batch 2:  batch loss at current step: 69.77764892578125
# Accuracy: 59.30%
# Epoch 78, CIFAR-10 Batch 3:  batch loss at current step: 67.7603530883789
# Accuracy: 60.26%
# Epoch 78, CIFAR-10 Batch 4:  batch loss at current step: 74.21683502197266
# Accuracy: 58.34%
# Epoch 78, CIFAR-10 Batch 5:  batch loss at current step: 68.04869079589844
# Accuracy: 60.30%
# Epoch 79, CIFAR-10 Batch 1:  batch loss at current step: 69.20894622802734
# Accuracy: 60.24%
# Epoch 79, CIFAR-10 Batch 2:  batch loss at current step: 67.65141296386719
# Accuracy: 59.98%
# Epoch 79, CIFAR-10 Batch 3:  batch loss at current step: 67.47972869873047
# Accuracy: 60.82%
# Epoch 79, CIFAR-10 Batch 4:  batch loss at current step: 67.88868713378906
# Accuracy: 59.42%
# Epoch 79, CIFAR-10 Batch 5:  batch loss at current step: 69.01768493652344
# Accuracy: 60.22%
# Epoch 80, CIFAR-10 Batch 1:  batch loss at current step: 71.04177856445312
# Accuracy: 59.20%
# Epoch 80, CIFAR-10 Batch 2:  batch loss at current step: 66.77214050292969
# Accuracy: 60.48%
# Epoch 80, CIFAR-10 Batch 3:  batch loss at current step: 68.30300903320312
# Accuracy: 61.02%
# Epoch 80, CIFAR-10 Batch 4:  batch loss at current step: 67.9115982055664
# Accuracy: 59.74%
# Epoch 80, CIFAR-10 Batch 5:  batch loss at current step: 70.56705474853516
# Accuracy: 59.64%
# Epoch 81, CIFAR-10 Batch 1:  batch loss at current step: 69.17121124267578
# Accuracy: 60.16%
# Epoch 81, CIFAR-10 Batch 2:  batch loss at current step: 69.08753967285156
# Accuracy: 61.02%
# Epoch 81, CIFAR-10 Batch 3:  batch loss at current step: 68.3971939086914
# Accuracy: 60.96%
# Epoch 81, CIFAR-10 Batch 4:  batch loss at current step: 67.69190979003906
# Accuracy: 59.44%
# Epoch 81, CIFAR-10 Batch 5:  batch loss at current step: 66.85313415527344
# Accuracy: 61.10%
# Epoch 82, CIFAR-10 Batch 1:  batch loss at current step: 66.7685775756836
# Accuracy: 60.84%
# Epoch 82, CIFAR-10 Batch 2:  batch loss at current step: 69.28855895996094
# Accuracy: 59.50%
# Epoch 82, CIFAR-10 Batch 3:  batch loss at current step: 68.86408996582031
# Accuracy: 60.30%
# Epoch 82, CIFAR-10 Batch 4:  batch loss at current step: 67.78765106201172
# Accuracy: 59.64%
# Epoch 82, CIFAR-10 Batch 5:  batch loss at current step: 66.08642578125
# Accuracy: 60.74%
# Epoch 83, CIFAR-10 Batch 1:  batch loss at current step: 66.82173919677734
# Accuracy: 61.00%
# Epoch 83, CIFAR-10 Batch 2:  batch loss at current step: 69.05702209472656
# Accuracy: 60.26%
# Epoch 83, CIFAR-10 Batch 3:  batch loss at current step: 70.28682708740234
# Accuracy: 59.96%
# Epoch 83, CIFAR-10 Batch 4:  batch loss at current step: 67.45203399658203
# Accuracy: 59.98%
# Epoch 83, CIFAR-10 Batch 5:  batch loss at current step: 67.7750473022461
# Accuracy: 59.50%
# Epoch 84, CIFAR-10 Batch 1:  batch loss at current step: 69.55382537841797
# Accuracy: 59.68%
# Epoch 84, CIFAR-10 Batch 2:  batch loss at current step: 69.9143295288086
# Accuracy: 60.02%
# Epoch 84, CIFAR-10 Batch 3:  batch loss at current step: 67.87000274658203
# Accuracy: 59.94%
# Epoch 84, CIFAR-10 Batch 4:  batch loss at current step: 68.1317138671875
# Accuracy: 59.98%
# Epoch 84, CIFAR-10 Batch 5:  batch loss at current step: 68.92412567138672
# Accuracy: 60.16%
# Epoch 85, CIFAR-10 Batch 1:  batch loss at current step: 68.09551239013672
# Accuracy: 60.54%
# Epoch 85, CIFAR-10 Batch 2:  batch loss at current step: 70.5895767211914
# Accuracy: 60.08%
# Epoch 85, CIFAR-10 Batch 3:  batch loss at current step: 67.98104858398438
# Accuracy: 60.70%
# Epoch 85, CIFAR-10 Batch 4:  batch loss at current step: 69.23216247558594
# Accuracy: 59.30%
# Epoch 85, CIFAR-10 Batch 5:  batch loss at current step: 68.79568481445312
# Accuracy: 59.56%
# Epoch 86, CIFAR-10 Batch 1:  batch loss at current step: 68.55607604980469
# Accuracy: 60.26%
# Epoch 86, CIFAR-10 Batch 2:  batch loss at current step: 66.6496353149414
# Accuracy: 60.22%
# Epoch 86, CIFAR-10 Batch 3:  batch loss at current step: 67.67471313476562
# Accuracy: 60.14%
# Epoch 86, CIFAR-10 Batch 4:  batch loss at current step: 69.6893539428711
# Accuracy: 60.34%
# Epoch 86, CIFAR-10 Batch 5:  batch loss at current step: 69.20813751220703
# Accuracy: 59.66%
# Epoch 87, CIFAR-10 Batch 1:  batch loss at current step: 67.5379409790039
# Accuracy: 59.92%
# Epoch 87, CIFAR-10 Batch 2:  batch loss at current step: 67.17461395263672
# Accuracy: 60.52%
# Epoch 87, CIFAR-10 Batch 3:  batch loss at current step: 65.2313232421875
# Accuracy: 61.34%
# Epoch 87, CIFAR-10 Batch 4:  batch loss at current step: 66.71614074707031
# Accuracy: 60.16%
# Epoch 87, CIFAR-10 Batch 5:  batch loss at current step: 67.06134033203125
# Accuracy: 59.88%
# Epoch 88, CIFAR-10 Batch 1:  batch loss at current step: 65.0436019897461
# Accuracy: 61.20%
# Epoch 88, CIFAR-10 Batch 2:  batch loss at current step: 68.7406234741211
# Accuracy: 60.28%
# Epoch 88, CIFAR-10 Batch 3:  batch loss at current step: 67.31236267089844
# Accuracy: 60.00%
# Epoch 88, CIFAR-10 Batch 4:  batch loss at current step: 68.05999755859375
# Accuracy: 59.56%
# Epoch 88, CIFAR-10 Batch 5:  batch loss at current step: 68.01361083984375
# Accuracy: 60.28%
# Epoch 89, CIFAR-10 Batch 1:  batch loss at current step: 67.35125732421875
# Accuracy: 59.72%
# Epoch 89, CIFAR-10 Batch 2:  batch loss at current step: 65.9298095703125
# Accuracy: 60.36%
# Epoch 89, CIFAR-10 Batch 3:  batch loss at current step: 68.8538818359375
# Accuracy: 59.54%
# Epoch 89, CIFAR-10 Batch 4:  batch loss at current step: 69.57691192626953
# Accuracy: 59.64%
# Epoch 89, CIFAR-10 Batch 5:  batch loss at current step: 72.5984115600586
# Accuracy: 59.28%
# Epoch 90, CIFAR-10 Batch 1:  batch loss at current step: 68.60552978515625
# Accuracy: 59.60%
# Epoch 90, CIFAR-10 Batch 2:  batch loss at current step: 66.07628631591797
# Accuracy: 59.84%
# Epoch 90, CIFAR-10 Batch 3:  batch loss at current step: 67.3853759765625
# Accuracy: 60.18%
# Epoch 90, CIFAR-10 Batch 4:  batch loss at current step: 68.78177642822266
# Accuracy: 59.26%
# Epoch 90, CIFAR-10 Batch 5:  batch loss at current step: 70.4661865234375
# Accuracy: 59.26%
# Epoch 91, CIFAR-10 Batch 1:  batch loss at current step: 68.04285430908203
# Accuracy: 60.00%
# Epoch 91, CIFAR-10 Batch 2:  batch loss at current step: 67.82868957519531
# Accuracy: 60.06%
# Epoch 91, CIFAR-10 Batch 3:  batch loss at current step: 66.06597137451172
# Accuracy: 59.94%
# Epoch 91, CIFAR-10 Batch 4:  batch loss at current step: 66.51741027832031
# Accuracy: 59.86%
# Epoch 91, CIFAR-10 Batch 5:  batch loss at current step: 69.82554626464844
# Accuracy: 59.42%
# Epoch 92, CIFAR-10 Batch 1:  batch loss at current step: 70.7979507446289
# Accuracy: 58.76%
# Epoch 92, CIFAR-10 Batch 2:  batch loss at current step: 66.54421997070312
# Accuracy: 60.06%
# Epoch 92, CIFAR-10 Batch 3:  batch loss at current step: 65.20968627929688
# Accuracy: 60.42%
# Epoch 92, CIFAR-10 Batch 4:  batch loss at current step: 67.95616149902344
# Accuracy: 59.80%
# Epoch 92, CIFAR-10 Batch 5:  batch loss at current step: 68.84971618652344
# Accuracy: 59.22%
# Epoch 93, CIFAR-10 Batch 1:  batch loss at current step: 66.05945587158203
# Accuracy: 60.44%
# Epoch 93, CIFAR-10 Batch 2:  batch loss at current step: 67.09043884277344
# Accuracy: 60.40%
# Epoch 93, CIFAR-10 Batch 3:  batch loss at current step: 68.67097473144531
# Accuracy: 60.52%
# Epoch 93, CIFAR-10 Batch 4:  batch loss at current step: 69.489990234375
# Accuracy: 59.40%
# Epoch 93, CIFAR-10 Batch 5:  batch loss at current step: 66.84566497802734
# Accuracy: 60.20%
# Epoch 94, CIFAR-10 Batch 1:  batch loss at current step: 66.4719467163086
# Accuracy: 59.80%
# Epoch 94, CIFAR-10 Batch 2:  batch loss at current step: 69.58797454833984
# Accuracy: 60.42%
# Epoch 94, CIFAR-10 Batch 3:  batch loss at current step: 66.90071868896484
# Accuracy: 60.28%
# Epoch 94, CIFAR-10 Batch 4:  batch loss at current step: 66.62342834472656
# Accuracy: 60.12%
# Epoch 94, CIFAR-10 Batch 5:  batch loss at current step: 66.17768096923828
# Accuracy: 60.50%
# Epoch 95, CIFAR-10 Batch 1:  batch loss at current step: 66.15076446533203
# Accuracy: 59.90%
# Epoch 95, CIFAR-10 Batch 2:  batch loss at current step: 67.84867858886719
# Accuracy: 59.50%
# Epoch 95, CIFAR-10 Batch 3:  batch loss at current step: 66.87275695800781
# Accuracy: 59.92%
# Epoch 95, CIFAR-10 Batch 4:  batch loss at current step: 67.95528411865234
# Accuracy: 59.12%
# Epoch 95, CIFAR-10 Batch 5:  batch loss at current step: 66.94369506835938
# Accuracy: 60.40%
# Epoch 96, CIFAR-10 Batch 1:  batch loss at current step: 69.73587036132812
# Accuracy: 59.36%
# Epoch 96, CIFAR-10 Batch 2:  batch loss at current step: 68.158203125
# Accuracy: 60.58%
# Epoch 96, CIFAR-10 Batch 3:  batch loss at current step: 68.21382141113281
# Accuracy: 59.92%
# Epoch 96, CIFAR-10 Batch 4:  batch loss at current step: 68.1807861328125
# Accuracy: 60.04%
# Epoch 96, CIFAR-10 Batch 5:  batch loss at current step: 65.94451141357422
# Accuracy: 60.20%
# Epoch 97, CIFAR-10 Batch 1:  batch loss at current step: 65.66485595703125
# Accuracy: 60.86%
# Epoch 97, CIFAR-10 Batch 2:  batch loss at current step: 67.1949234008789
# Accuracy: 60.20%
# Epoch 97, CIFAR-10 Batch 3:  batch loss at current step: 67.00542449951172
# Accuracy: 60.64%
# Epoch 97, CIFAR-10 Batch 4:  batch loss at current step: 68.19906616210938
# Accuracy: 60.62%
# Epoch 97, CIFAR-10 Batch 5:  batch loss at current step: 69.65752410888672
# Accuracy: 60.66%
# Epoch 98, CIFAR-10 Batch 1:  batch loss at current step: 68.65357208251953
# Accuracy: 60.42%
# Epoch 98, CIFAR-10 Batch 2:  batch loss at current step: 68.52013397216797
# Accuracy: 60.42%
# Epoch 98, CIFAR-10 Batch 3:  batch loss at current step: 68.30180358886719
# Accuracy: 59.26%
# Epoch 98, CIFAR-10 Batch 4:  batch loss at current step: 69.79421997070312
# Accuracy: 60.20%
# Epoch 98, CIFAR-10 Batch 5:  batch loss at current step: 69.55728912353516
# Accuracy: 59.52%
# Epoch 99, CIFAR-10 Batch 1:  batch loss at current step: 65.69548034667969
# Accuracy: 60.28%
# Epoch 99, CIFAR-10 Batch 2:  batch loss at current step: 66.76895141601562
# Accuracy: 60.10%
# Epoch 99, CIFAR-10 Batch 3:  batch loss at current step: 64.96005249023438
# Accuracy: 60.36%
# Epoch 99, CIFAR-10 Batch 4:  batch loss at current step: 67.89672088623047
# Accuracy: 60.12%
# Epoch 99, CIFAR-10 Batch 5:  batch loss at current step: 65.9983901977539
# Accuracy: 60.90%
# Epoch 100, CIFAR-10 Batch 1:  batch loss at current step: 66.64185333251953
# Accuracy: 60.56%
# Epoch 100, CIFAR-10 Batch 2:  batch loss at current step: 66.61196899414062
# Accuracy: 59.64%
# Epoch 100, CIFAR-10 Batch 3:  batch loss at current step: 66.32268524169922
# Accuracy: 59.98%
# Epoch 100, CIFAR-10 Batch 4:  batch loss at current step: 65.63318634033203
# Accuracy: 60.90%
# Epoch 100, CIFAR-10 Batch 5:  batch loss at current step: 65.90422821044922
# Accuracy: 60.36%

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.5989912974683544

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recommend that once you are done with this project, you explore!
#
# ## Submitting This Project
# >When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
